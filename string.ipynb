# %%
print("hello world")
# Out:
# hello world

# %%
def greet(name):
    return "hello {}.Welcome to python programming".format(name)

# %%
def welcome(first,last):
    return "hello {}.Welcome to python{} programming".format(last,first)

# %%
welcome("shylesh"," S")
# Out:
# 'hello  S.Welcome to pythonshylesh programming'

# %%
greet("shylesh")
# Out:
# 'hello shylesh.Welcome to python programming'
