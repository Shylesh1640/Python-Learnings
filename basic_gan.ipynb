# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

def define_generator(latent_dim, output_dim=1):
    model = Sequential()
    model.add(Dense(10, activation='relu', input_dim=latent_dim))
    model.add(Dense(output_dim, activation='linear'))
    return model

def define_discriminator(input_dim=1):
    model = Sequential()
    model.add(Dense(10, activation='relu', input_dim=input_dim))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

def define_gan(generator, discriminator):
    discriminator.trainable = False
    model = Sequential()
    model.add(generator)
    model.add(discriminator)
    model.compile(loss='binary_crossentropy', optimizer='adam')
    return model

def generate_real_samples(n):
    x = np.random.rand(n)
    y = np.ones((n, 1))
    return x, y

def generate_latent_points(latent_dim, n):
    return np.random.randn(n, latent_dim)

def train_gan(generator, discriminator, gan_model, latent_dim, n_epochs=100, n_batch=128):
    half_batch = int(n_batch / 2)
    
    for epoch in range(n_epochs):
        # Train Discriminator
        x_real, y_real = generate_real_samples(half_batch)
        d_loss_real, _ = discriminator.train_on_batch(x_real, y_real)

        x_fake = generator.predict(generate_latent_points(latent_dim, half_batch))
        y_fake = np.zeros((half_batch, 1))
        d_loss_fake, _ = discriminator.train_on_batch(x_fake, y_fake)

        # Train Generator
        x_gan = generate_latent_points(latent_dim, n_batch)
        y_gan = np.ones((n_batch, 1))
        g_loss = gan_model.train_on_batch(x_gan, y_gan)

        if (epoch + 1) % 2 == 0:
            print(f'Epoch {epoch+1}, D Loss Real: {d_loss_real:.3f}, D Loss Fake: {d_loss_fake:.3f}, G Loss: {g_loss:.3f}')

latent_dim = 5

discriminator = define_discriminator()
discriminator.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

generator = define_generator(latent_dim)
gan_model = define_gan(generator, discriminator)

train_gan(generator, discriminator, gan_model, latent_dim)
# Out:
# c:\Users\Shylesh\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Shylesh\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:86: UserWarning: The model does not have any trainable weights.
#   warnings.warn("The model does not have any trainable weights.")
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Epoch 2, D Loss Real: 0.691, D Loss Fake: 0.683, G Loss: 0.721
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Epoch 4, D Loss Real: 0.686, D Loss Fake: 0.683, G Loss: 0.723
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Epoch 6, D Loss Real: 0.685, D Loss Fake: 0.683, G Loss: 0.723
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Epoch 8, D Loss Real: 0.685, D Loss Fake: 0.683, G Loss: 0.723
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Epoch 10, D Loss Real: 0.685, D Loss Fake: 0.684, G Loss: 0.724
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Epoch 12, D Loss Real: 0.685, D Loss Fake: 0.684, G Loss: 0.723
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Epoch 14, D Loss Real: 0.685, D Loss Fake: 0.684, G Loss: 0.722
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Epoch 16, D Loss Real: 0.685, D Loss Fake: 0.684, G Loss: 0.722
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Epoch 18, D Loss Real: 0.685, D Loss Fake: 0.685, G Loss: 0.722
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Epoch 20, D Loss Real: 0.685, D Loss Fake: 0.685, G Loss: 0.721
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Epoch 22, D Loss Real: 0.685, D Loss Fake: 0.685, G Loss: 0.721
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Epoch 24, D Loss Real: 0.686, D Loss Fake: 0.685, G Loss: 0.720
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Epoch 26, D Loss Real: 0.686, D Loss Fake: 0.685, G Loss: 0.720
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Epoch 28, D Loss Real: 0.686, D Loss Fake: 0.686, G Loss: 0.720
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Epoch 30, D Loss Real: 0.686, D Loss Fake: 0.686, G Loss: 0.719
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Epoch 32, D Loss Real: 0.686, D Loss Fake: 0.686, G Loss: 0.719
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Epoch 34, D Loss Real: 0.686, D Loss Fake: 0.686, G Loss: 0.719
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Epoch 36, D Loss Real: 0.686, D Loss Fake: 0.686, G Loss: 0.719
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Epoch 38, D Loss Real: 0.687, D Loss Fake: 0.686, G Loss: 0.718
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Epoch 40, D Loss Real: 0.687, D Loss Fake: 0.686, G Loss: 0.718
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Epoch 42, D Loss Real: 0.687, D Loss Fake: 0.687, G Loss: 0.718
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Epoch 44, D Loss Real: 0.687, D Loss Fake: 0.687, G Loss: 0.717
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Epoch 46, D Loss Real: 0.687, D Loss Fake: 0.687, G Loss: 0.717
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Epoch 48, D Loss Real: 0.687, D Loss Fake: 0.687, G Loss: 0.717
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Epoch 50, D Loss Real: 0.687, D Loss Fake: 0.687, G Loss: 0.717
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Epoch 52, D Loss Real: 0.687, D Loss Fake: 0.687, G Loss: 0.717
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Epoch 54, D Loss Real: 0.687, D Loss Fake: 0.687, G Loss: 0.716
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Epoch 56, D Loss Real: 0.687, D Loss Fake: 0.687, G Loss: 0.716
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Epoch 58, D Loss Real: 0.687, D Loss Fake: 0.687, G Loss: 0.716
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Epoch 60, D Loss Real: 0.688, D Loss Fake: 0.687, G Loss: 0.716
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Epoch 62, D Loss Real: 0.688, D Loss Fake: 0.688, G Loss: 0.716
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Epoch 64, D Loss Real: 0.688, D Loss Fake: 0.688, G Loss: 0.715
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Epoch 66, D Loss Real: 0.688, D Loss Fake: 0.688, G Loss: 0.715
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Epoch 68, D Loss Real: 0.688, D Loss Fake: 0.688, G Loss: 0.715
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Epoch 70, D Loss Real: 0.688, D Loss Fake: 0.688, G Loss: 0.715
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Epoch 72, D Loss Real: 0.688, D Loss Fake: 0.688, G Loss: 0.715
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Epoch 74, D Loss Real: 0.688, D Loss Fake: 0.688, G Loss: 0.714
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Epoch 76, D Loss Real: 0.688, D Loss Fake: 0.688, G Loss: 0.714
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Epoch 78, D Loss Real: 0.688, D Loss Fake: 0.688, G Loss: 0.714
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Epoch 80, D Loss Real: 0.688, D Loss Fake: 0.688, G Loss: 0.714
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Epoch 82, D Loss Real: 0.688, D Loss Fake: 0.688, G Loss: 0.714
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Epoch 84, D Loss Real: 0.688, D Loss Fake: 0.688, G Loss: 0.714
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Epoch 86, D Loss Real: 0.688, D Loss Fake: 0.688, G Loss: 0.713
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Epoch 88, D Loss Real: 0.688, D Loss Fake: 0.688, G Loss: 0.713
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Epoch 90, D Loss Real: 0.689, D Loss Fake: 0.688, G Loss: 0.713
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Epoch 92, D Loss Real: 0.689, D Loss Fake: 0.689, G Loss: 0.713
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Epoch 94, D Loss Real: 0.689, D Loss Fake: 0.689, G Loss: 0.713
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Epoch 96, D Loss Real: 0.689, D Loss Fake: 0.689, G Loss: 0.713
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Epoch 98, D Loss Real: 0.689, D Loss Fake: 0.689, G Loss: 0.713
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Epoch 100, D Loss Real: 0.689, D Loss Fake: 0.689, G Loss: 0.712
