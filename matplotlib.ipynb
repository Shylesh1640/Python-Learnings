# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import numpy as np

# %%
x = np.arange(0, 10)
y = np.arange(11,21)

# %%
a = np.arange(40, 50)
b = np.arange(50, 60)

# %%
##ploting using matplotlib
##plt scatter

plt.scatter(x,y,c='g')
plt.xlabel("X axis")
plt.ylabel("Y axis")    
plt.title("Scatter Plot")
plt.savefig("test1.png")

# %%
y = x*x

# %%
plt.plot(x,y,'r*-')
plt.xlabel("X axis")
plt.ylabel("Y axis")    
plt.title("Line Plot")
# Out:
# Text(0.5, 1.0, 'Line Plot')

# %%
plt.subplot(2,2,1)
plt.plot(x,y,'r*-')
plt.subplot(2,2,2)
plt.plot(x,y,'g^--')
plt.subplot(2,2,3)
plt.plot(a,b,'bs-')

# %%
plt.plot(x,y,'r',linestyle='dashed',marker='o',markerfacecolor='blue',markersize=10)
plt.xlabel("X axis")
plt.ylabel("Y axis")        
plt.title("Line Plot with different style")
# Out:
# Text(0.5, 1.0, 'Line Plot with different style')

# %%
x = np.arange(1,11)
y = 3*x + 5
plt.plot(x,y,'g--')
plt.xlabel("X axis")
plt.ylabel("Y axis")    
plt.title("Line Plot with slope 3 and intercept 5")
# Out:
# Text(0.5, 1.0, 'Line Plot with slope 3 and intercept 5')

# %%
np.pi
# Out:
# 3.141592653589793

# %%
#compute the x and y cordinates for points on a sine curve
x = np.arange(0, 4 * np.pi, 0.1)
y = np.sin(x)
plt.plot(x, y)
plt.xlabel("X axis")
plt.ylabel("Y axis")
plt.title("Sine Wave")
# Out:
# Text(0.5, 1.0, 'Sine Wave')

# %%
#Subplot()
#Compute the x and y coordinates for points on sine and cosine curves
x = np.arange(0, 5 * np.pi, 0.1)
y_sin = np.sin(x)
y_cos = np.cos(x)

#Set up a subplot grid that has height 2 and width 1, 
#and set the first subplot as active
plt.subplot(2, 1, 1)

#Make the first plot
plt.plot(x, y_sin, 'r--')
plt.title('Sine')

#Set the second subplot as active, and make the second plot
plt.subplot(2, 1, 2)
plt.plot(x, y_cos, 'b-')
plt.title('Cosine') 

#Show the figure
plt.show()

# %%
#Bar plot

x = [2,8,10]
y = [11,16,5]

x2 = [3,9,6]
y2 = [6,15,7]   

plt.bar(x, y)
plt.bar(x2, y2, color='g')
plt.title("Bar Plot ")
plt.xlabel("X axis")
plt.ylabel("Y axis")
# Out:
# Text(0, 0.5, 'Y axis')

# %%
#Histogram

a = np.array([22, 87, 5, 43, 56, 73, 55, 54, 11, 20, 51, 5, 79, 31, 27])
plt.hist(a)
plt.title("Histogram")
# Out:
# Text(0.5, 1.0, 'Histogram')

# %%
#Box plot

data = [np.random.normal(0, std, 100) for std in range(1, 4)]

#rectangle box plot
plt.boxplot(data,vert=True,patch_artist=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2c348c60380>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2c348c60d40>,
# ...
#  'boxes': [<matplotlib.patches.PathPatch at 0x2c348c61f40>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x2c348c51430>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x2c348c51490>,
# ...
#  'means': []}

# %%
#pie chart

#data to plot 
lables = 'Python','C++','Ruby','Java'
sizes = [215,130,245,210]
colors = ['gold','yellowgreen','lightcoral','lightskyblue']
explode = (0.1,0,0,0) #explode 1st slice

#plot
plt.pie(sizes,explode=explode,labels=lables,colors=colors,autopct='%1.1f%%',shadow=True,startangle=140)

plt.axis('equal')
# Out:
# (np.float64(-1.2038796743934574),
#  np.float64(1.1049454474853655),
#  np.float64(-1.099999752591364),
#  np.float64(1.0999999777417189))
