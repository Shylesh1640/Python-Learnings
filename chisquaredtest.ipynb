# %%
import scipy.stats as stats

# %%
import seaborn as sns
import pandas as pd
import numpy as np
dataset = sns.load_dataset("tips")

# %%
dataset.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
dataset_table = pd.crosstab(dataset['sex'], dataset['smoker'])
print(dataset_table)
# Out:
# smoker  Yes  No
# sex
# Male     60  97
# Female   33  54

# %%
observed_Values = dataset_table.values
print("Observed Values :-\n",observed_Values)
# Out:
# Observed Values :-
#  [[60 97]
#  [33 54]]

# %%
val = stats.chi2_contingency(dataset_table)

# %%
val
# Out:
# Chi2ContingencyResult(statistic=0.0, pvalue=1.0, dof=1, expected_freq=array([[59.84016393, 97.15983607],
#        [33.15983607, 53.84016393]]))

# %%
Expected_Values = val[3]

# %%
no_of_rows = len(dataset_table.iloc[0:2,0])
no_of_columns = len(dataset_table.iloc[0,0:2])
ddof = (no_of_rows-1)*(no_of_columns-1)
print("Degree of Freedom:-",ddof)       
alpha = 0.05
# Out:
# Degree of Freedom:- 1

# %%
from scipy.stats import chi2
chi_square = sum([(o-e)**2./e for o,e in zip(observed_Values,Expected_Values)])
chi_square_statistic = chi_square[0] + chi_square[1]

# %%
print("Chi-Square Statistic:-",chi_square_statistic)
# Out:
# Chi-Square Statistic:- 0.001934818536627623

# %%
critical_value = chi2.ppf(q=1-alpha, df=ddof)
print("Critical Value:-",critical_value)
# Out:
# Critical Value:- 3.841458820694124

# %%
p_value = 1 - chi2.cdf(x=chi_square_statistic, df=ddof)
print("P-Value:-",p_value)
print("Significance Level:-",alpha)
print("Degree of Freedom:-",ddof)
print("p_value:",p_value)
# Out:
# P-Value:- 0.964915107315732
# Significance Level:- 0.05
# Degree of Freedom:- 1
# p_value: 0.964915107315732

# %%
if chi_square_statistic >= critical_value:
    print("Reject Ho, There is a relationship between the variables")
else:
    print("Accept Ho, There is no relationship between the variables")

if p_value <= alpha:
    print("Reject Ho, There is a relationship between the variables")
else:
    print("Accept Ho, There is no relationship between the variables")
# Out:
# Accept Ho, There is no relationship between the variables
# Accept Ho, There is no relationship between the variables
