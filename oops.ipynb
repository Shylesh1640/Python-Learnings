# %%
class car:
    def __init__(self, window , door , engine):
        self.window = window
        self.door = door
        self.engine = engine
        
    def selfdrive(self):
        return f"The car with {self.engine} engine is self driving"

# %%
dir(car1)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'doors',
#  'engine',
#  'windows']

# %%
car1.windows = 5

# %%
car1.doors=4

# %%
car1.engine = "petrol"

# %%
car1 = car(4, 4, "diesel")

# %%
print(car1.window)
# Out:
# 4

# %%
print(car1.door)
# Out:
# 4

# %%
print(car1.engine)
# Out:
# diesel

# %%
car2 = car(6, 4, "electric")

# %%
print(car2.door)
# Out:
# 4

# %%
car1.selfdrive
# Out:
# <bound method car.selfdrive of <__main__.car object at 0x00000276A9CCFD10>>

# %%
car1.selfdrive()
# Out:
# 'The car with diesel engine is self driving'
